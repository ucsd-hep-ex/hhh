# %%
from datetime import datetime
date = datetime.today().strftime('%Y-%m-%d')
print(date)
# Out:
# 2024-12-04

# %%
# !pip install -e ../. --quiet

# %%
# !pip install --upgrade awkward --quiet
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# coffea 0.7.20 requires awkward<2,>=1.5.1, but you have awkward 2.7.1 which is incompatible.

# %%
from src.analysis.plot import plot_pur_eff_w_dict
# Out:
# /Users/billyli/miniforge_x86_new/lib/python3.9/site-packages/coffea/util.py:154: FutureWarning: In coffea version v0.8.0 (target date: 31 Dec 2022), this will be an error.
# (Set coffea.deprecations_as_errors = True to get a stack trace now.)
# ImportError: coffea.hist is deprecated
#   warnings.warn(message, FutureWarning)

# %%
target_path = '../data/hhh_mh125_testing.h5'

# %%
plot_dict = {}
plot_dict['SPA-Net'] = "../predictions/hhh_br_spanet_west.h5"
plot_dict['Baseline'] = "../predictions/hhh_chi2_loose_bdt_baseline_predictions_west.h5"

# %%
plot_pur_eff_w_dict(plot_dict, target_path, save_path="../plots/HHH/B+R/", proj_name=date)
# Out:
# Processing SPA-Net
# Average purity:
# merged 0.4079620482222331 boosted 0.5942420868458724 resolved 0.40202564893394754
# Average efficiency:
# merged 0.5062963581292185 boosted 0.8696461824953445 resolved 0.4939249480503606
# Number of correct Higgs canddiate predictions
# merged 41708.0 boosted 7472.0 resolved 40408.0
# Number of reconstructed Higgs targets
# merged 42457.0 boosted 7472.0 resolved 40408.0
# Number of Boosted Prediction: 12574
# Number of Resolved Prediction before OR: 100511
# Number of Resolved Prediction after OR: 89661
# Processing Baseline
# Average purity:
# merged 0.2603789454010233 boosted 0.8507501974203738 resolved 0.2507880174648019
# Average efficiency:
# merged 0.3671325335686518 boosted 0.3761638733705773 resolved 0.3938760542720939
# Number of correct Higgs canddiate predictions
# merged 33435.0 boosted 3232.0 resolved 32223.0
# Number of reconstructed Higgs targets
# merged 30787.0 boosted 3232.0 resolved 32223.0
# ...
