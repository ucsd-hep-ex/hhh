# %% [markdown]
# Side note: we are evaluating particle level information
# maybe we should also do the event level information

# %%
from datetime import datetime
date = datetime.today().strftime('%Y-%m-%d')
print(date)
# Out:
# 2024-12-04

# %%
# !pip install -e ../. --quiet

# %%
# !pip install --upgrade awkward --quiet
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# coffea 0.7.20 requires awkward<2,>=1.5.1, but you have awkward 2.7.1 which is incompatible.

# %%
from src.analysis.plot import plot_pur_eff_w_dict
# Out:
# /Users/billyli/miniforge_x86_new/lib/python3.9/site-packages/coffea/util.py:154: FutureWarning: In coffea version v0.8.0 (target date: 31 Dec 2022), this will be an error.
# (Set coffea.deprecations_as_errors = True to get a stack trace now.)
# ImportError: coffea.hist is deprecated
#   warnings.warn(message, FutureWarning)

# %%
target_path = '../data/hh_mh125_testing.h5'

# %%
plot_dict = {}
plot_dict['SPA-Net'] = "../predictions/hh_br_spanet_west.h5"
plot_dict['Baseline'] = "../predictions/hh_chi2_loose_bdt_baseline_predictions_west.h5"

# %%
plot_pur_eff_w_dict(plot_dict, target_path, save_path="../plots/HH/B+R/",
                    num_higgs=2,
                    proj_name=date)
# Out:
# Processing SPA-Net
# Average purity:
# merged 0.6514093820799742 boosted 0.8429050279329608 resolved 0.6469421293579058
# Average efficiency:
# merged 0.6739282021688427 boosted 0.8225032708242477 resolved 0.6776466248616747
# Number of correct Higgs canddiate predictions
# merged 56642.0 boosted 7544.0 resolved 55113.0
# Number of reconstructed Higgs targets
# merged 56056.0 boosted 7544.0 resolved 55113.0
# Number of Boosted Prediction: 8950
# Number of Resolved Prediction before OR: 85190
# Number of Resolved Prediction after OR: 78003
# Processing Baseline
# Average purity:
# merged 0.40178290073803796 boosted 0.9255400254129607 resolved 0.38959565339826735
# Average efficiency:
# merged 0.5467912188319026 boosted 0.39707806367204534 resolved 0.57837206442887
# Number of correct Higgs canddiate predictions
# merged 48451.0 boosted 3642.0 resolved 47039.0
# Number of reconstructed Higgs targets
# merged 45481.0 boosted 3642.0 resolved 47039.0
# Number of Boosted Prediction: 3935
# ...
